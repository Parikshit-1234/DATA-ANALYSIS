# %%
import pandas as pd

# %%
data = pd.read_csv("D:\GAME SETUPS\data.csv")

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# # SHAPE OF DATA

# %%
data.shape
# Out:
# (8784, 8)

# %% [markdown]
# # ALL UNIQUE VALUES OF WEATHER

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %% [markdown]
# # COUNTS WHERE WEATHER WAS UNIQUE

# %%
data['Weather'].nunique()
# Out:
# 50

# %% [markdown]
# # UNIQUE VALUES IN ALL COLUMNS

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %% [markdown]
# # COUNTS OF WEATHER VALUES

# %%
data.Weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %% [markdown]
# # DATA WHERE WEATHER WAS CLEAR

# %%
data[data.Weather == "Clear"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
data.groupby('Weather').get_group('Clear')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# # WIND SPEED WAS EXACTLY 7KM/HR

# %%
data[data["Wind Speed_km/h"] == 7]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# 7        1/1/2012 7:00    -1.4              -3.6         85                7
# 11      1/1/2012 11:00    -0.5              -2.1         89                7
# ...                ...     ...               ...        ...              ...
# 8647   12/26/2012 7:00   -13.0             -14.4         89                7
# 8693   12/28/2012 5:00    -5.0              -6.1         92                7
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
# 8723  12/29/2012 11:00   -10.9             -12.2         90                7
#
# ...

# %% [markdown]
# # NULL DATA

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data[data.isnull()]
# Out:
#      Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0          NaN     NaN               NaN        NaN              NaN
# 1          NaN     NaN               NaN        NaN              NaN
# 2          NaN     NaN               NaN        NaN              NaN
# 3          NaN     NaN               NaN        NaN              NaN
# 4          NaN     NaN               NaN        NaN              NaN
# ...        ...     ...               ...        ...              ...
# 8779       NaN     NaN               NaN        NaN              NaN
# 8780       NaN     NaN               NaN        NaN              NaN
# 8781       NaN     NaN               NaN        NaN              NaN
# 8782       NaN     NaN               NaN        NaN              NaN
# 8783       NaN     NaN               NaN        NaN              NaN
#
#       Visibility_km  Press_kPa Weather
# 0               NaN        NaN     NaN
# 1               NaN        NaN     NaN
# ...

# %%
data.isnull()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# ...         ...     ...               ...        ...              ...
# 8779      False   False             False      False            False
# 8780      False   False             False      False            False
# 8781      False   False             False      False            False
# 8782      False   False             False      False            False
# 8783      False   False             False      False            False
#
#       Visibility_km  Press_kPa  Weather
# 0             False      False    False
# 1             False      False    False
# ...

# %% [markdown]
# # NOT NULL VALUES

# %%
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data[data.notnull()]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# # TEMPORARY RENAMING A COLUMN

# %%
data.rename(columns = {'Weather':'Weather type'})
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# # PERMANENTLY RENAMING A COLUMN

# %%
data.rename(columns = {'Weather':'Weather Types'},inplace = True)

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# # MEAN OF A COLUMN

# %%
data.Visibility_km.mean()
# Out:
# 27.664446721311478

# %% [markdown]
# # STANDERED DEVIATION IN PRESSURE

# %%
data.Press_kPa.std()
# Out:
# 0.8440047459486483

# %% [markdown]
# # VARIANCE OF HUMIDITY

# %%
data['Rel Hum_%'].var()
# Out:
# 286.24855019850196

# %%
data[data['Weather Types'] == "Snow"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather Types
# ...

# %%
data[data['Weather Types'].str.contains("Snow")]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather Types
# ...

# %%
data['Weather Types'].str.contains("Snow").count()
# Out:
# 8784

# %%
data['Weather Types'].str.contains("Snow").nunique()
# Out:
# 2

# %%
data['Weather Types'].str.contains("Snow").unique()
# Out:
# array([False,  True])

# %%
data['Weather Types'].str.contains("Snow").value_counts()
# Out:
# False    8201
# True      583
# Name: Weather Types, dtype: int64

# %%
data[data['Weather Types'].str.contains("Snow")].tail(10)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8774  12/31/2012 14:00    -3.4              -5.7         84                6
# 8775  12/31/2012 15:00    -2.3              -4.6         84                9
# 8776  12/31/2012 16:00    -1.4              -4.0         82               13
# 8777  12/31/2012 17:00    -1.1              -3.3         85               19
# 8778  12/31/2012 18:00    -1.3              -3.1         88               17
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather Types
# 8774           11.3     100.57          Snow
# ...

# %%
data[(data['Dew Point Temp_C']>0) & (data['Rel Hum_%']>=85)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 19      1/1/2012 19:00     3.1               1.3         88               15
# 20      1/1/2012 20:00     3.2               1.3         87               19
# 21      1/1/2012 21:00     4.0               1.7         85               20
# 408     1/18/2012 0:00     2.1               0.7         90               11
# 546    1/23/2012 18:00     3.0               1.2         88               19
# ...                ...     ...               ...        ...              ...
# 8540  12/21/2012 20:00     2.4               1.7         95               15
# 8541  12/21/2012 21:00     1.3               0.4         94               22
# 8545   12/22/2012 1:00     1.2               0.1         92               30
# 8546   12/22/2012 2:00     1.1               0.1         93               30
# 8547   12/22/2012 3:00     1.1               0.1         93               28
#
# ...

# %%
arr = data[(data['Dew Point Temp_C']>0) & (data['Rel Hum_%']>=85)]

# %%
arr.shape
# Out:
# (1080, 8)

# %% [markdown]
# # MEAN VALUE OF EACH WEATHER CONDITION

# %%
data.groupby("Weather Types").mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1192\323296799.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby("Weather Types").mean()
#                                             Temp_C  Dew Point Temp_C  \
# Weather Types
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# ...

# %%
data.groupby("Weather Types").min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather Types
# Clear                                      1/11/2012 1:00   -23.3
# Cloudy                                     1/1/2012 17:00   -21.4
# Drizzle                                   1/23/2012 21:00     1.1
# Drizzle,Fog                               1/23/2012 20:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                         1/1/2012 0:00   -16.0
# Freezing Drizzle                          1/13/2012 10:00    -9.0
# Freezing Drizzle,Fog                        1/1/2012 2:00    -6.4
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -8.3
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %%
data.groupby("Weather Types").max()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather Types
# Clear                                       9/9/2012 5:00    32.8
# Cloudy                                     9/9/2012 23:00    30.5
# Drizzle                                    9/30/2012 3:00    18.8
# Drizzle,Fog                                9/30/2012 2:00    19.9
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/19/2012 18:00     1.2
# Drizzle,Snow,Fog                          12/22/2012 3:00     1.1
# Fog                                        9/22/2012 0:00    20.8
# Freezing Drizzle                            2/1/2012 5:00    -2.3
# Freezing Drizzle,Fog                      12/10/2012 5:00    -0.3
# Freezing Drizzle,Haze                      2/1/2012 13:00    -5.0
# Freezing Drizzle,Snow                      3/2/2012 12:00    -3.3
# Freezing Fog                               3/17/2012 6:00    -0.1
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5,6,7,8])

# %%
arr2 = np.array([1,4,9,16,25,36,49,64])

# %%
plt.plot(arr1,arr2)
plt.show()

# %%
data[data["Weather Types"] == 'Fog'].tail(10)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8336   12/13/2012 8:00    -6.0              -7.1         92                4
# 8337   12/13/2012 9:00    -4.7              -6.0         91                4
# 8338  12/13/2012 10:00    -2.3              -4.2         87                4
# 8483  12/19/2012 11:00     0.8               0.2         96               11
# 8715   12/29/2012 3:00   -13.4             -15.2         86                4
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
#       Visibility_km  Press_kPa Weather Types
# 8336            8.0     102.67           Fog
# ...

# %%
data[(data['Weather Types'] == "Fog") & (data['Visibility_km']>6)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# 7        1/1/2012 7:00    -1.4              -3.6         85                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
#       Visibility_km  Press_kPa Weather Types
# ...

# %%
data[(data['Temp_C']<-10) & (data['Rel Hum_%']>86)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8306   12/12/2012 2:00   -10.3             -12.0         87                4
# 8308   12/12/2012 4:00   -10.1             -11.6         89                6
# 8309   12/12/2012 5:00   -10.3             -11.7         89                4
# 8311   12/12/2012 7:00   -11.2             -12.4         91                4
# 8640   12/26/2012 0:00   -11.8             -13.5         87                4
# 8641   12/26/2012 1:00   -11.2             -12.9         87                6
# 8642   12/26/2012 2:00   -12.7             -14.4         87                4
# 8643   12/26/2012 3:00   -14.2             -15.8         88                6
# 8644   12/26/2012 4:00   -13.1             -14.7         88                6
# 8645   12/26/2012 5:00   -12.7             -14.1         89                4
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# ...

# %%
data[(data['Dew Point Temp_C']<-12) & (data['Wind Speed_km/h']>8)].tail(10)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8754  12/30/2012 18:00   -12.6             -16.0         76               24
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
# 8757  12/30/2012 21:00   -13.8             -16.5         80               20
# 8758  12/30/2012 22:00   -13.7             -16.3         81               19
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
# 8761   12/31/2012 1:00   -10.7             -14.0         77               15
# 8762   12/31/2012 2:00   -10.1             -13.4         77                9
# 8764   12/31/2012 4:00   -10.5             -12.8         83               11
#
#       Visibility_km  Press_kPa  Weather Types
# 8754           25.0     101.36   Mainly Clear
# ...
